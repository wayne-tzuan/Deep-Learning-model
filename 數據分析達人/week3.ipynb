# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
np.sin(3)
# Out:
# 0.1411200080598672

# %%
np.cos(3)
# Out:
# -0.9899924966004454

# %%
np.pi
# Out:
# 3.141592653589793

# %%
x = [1,2,3,4,5,6]
y = [7,8,9,10,11,12]
plt.plot(x,y)

# %%
plt.plot(np.random.randn(100))
