# %%
1+1
# Out:
# 2

# %%
4 + 6*4
# Out:
# 28

# %%
2**3
# Out:
# 8

# %%
8/3
# Out:
# 2.6666666666666665

# %%
8%3
# Out:
# 2

# %%
3000*0.05*200
# Out:
# 30000.0

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pi
# Out:
# 3.141592653589793

# %%
sin(pi/2)
# Out:
# 1.0

# %%
plot([-1, 2, 6, 10, 8, 7])

# %%
randn(50)
# Out:
# array([-0.44311264,  0.541039  , -0.39661901,  0.99354725, -0.05287003,
#         0.7168155 ,  0.21061048, -1.0587844 , -0.02422525, -0.79954331,
#         0.80771796,  0.63653768,  0.27691598,  0.87184676, -0.26391515,
#        -0.00187918,  1.55047003, -0.12838591, -1.80419577, -1.49591513,
#        -1.06945603, -0.46371203,  0.02644921,  1.8193805 ,  0.70789692,
#         0.24574243, -0.05769752, -0.04300248, -1.54260987,  0.2109144 ,
#         0.8070005 ,  0.55552412, -0.54189067, -0.22331458, -1.5334582 ,
#        -1.6036211 ,  1.42585021,  0.43340051,  0.20827658, -0.27434996,
#         0.29919994, -0.17003018, -0.09328164,  0.61497701,  0.00651716,
#         1.62701762, -1.49615748, -0.34520966, -0.02171432, -0.67121442])

# %%
plot(randn(50))

# %%
x = [1, 2, 3, 4]
y = [-1, -2, -3, -4]
plot(x,y)

# %% [markdown]
# 利用 Markdown 做筆記！

# %% [markdown]
# #利用 Markdown 做筆記
# ##用井字數量區分標題大小

# %% [markdown]
# ＃利用 Markdown 做筆記

# %% [markdown]
# # 利用 Markdown 做筆記
# ## 用井字數量區分標題大小
# ### 詳見內文。

# %% [markdown]
# ## 分項說明
#
# * Python
# * Jupyter Notebook
# * Numpy
# * Pandas
# * Matpoltlib

# %% [markdown]
# ## 連結
# [ 政大磨課師 ] (http://moocs.nccu.edu.tw/media/17832)

# %% [markdown]
# ## 連結
# [政大磨課師](http://moocs.nccu.edu.tw/media/17832)

# %% [markdown]
# ## 生日快樂
# ![董小姐](1.jpg)

# %% [markdown]
# ## 打數學符號
#
# 我們有一個函數 $f(x) = x^2 + 2x +1$, 我想給它積分:
#
# $$ \int_a^b f(x) \, dx$$

# %%
底 = 3
高 = 7

# %%
底
# Out:
# 3

# %%
面積 = 底 * 高 / 2

# %%
面積
# Out:
# 10.5

# %%
L = [1, 3, 5, 7, 9]
G = [-2, 4, -6, 8, -10]

# %%
L + G
# Out:
# [1, 3, 5, 7, 9, -2, 4, -6, 8, -10]

# %%
L - G
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-9d7050e65523> in <module>
# ----> 1 L - G
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
L * G
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-65766000e348> in <module>
# ----> 1 L * G
#
# TypeError: can't multiply sequence by non-int of type 'list'

# %%
3*L
# Out:
# [1, 3, 5, 7, 9, 1, 3, 5, 7, 9, 1, 3, 5, 7, 9]

# %% [markdown]
# ## Hello, World!

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
name = "tzuan"

# %%
name
# Out:
# 'tzuan'

# %%
"hello, " + name + "!"
# Out:
# 'hello, tzuan!'

# %%
hi = "Hi, "
hi + name
# Out:
# 'Hi, tzuan'

# %%
5*name
# Out:
# 'tzuantzuantzuantzuantzuan'

# %%
message = '''我來示範
中間換行
就這樣。
'''

# %%
message
# Out:
# '我來示範\n中間換行\n就這樣。\n'

# %%
print(message)
# Out:
# 我來示範
# 中間換行
# 就這樣。

# %%
message = '我來示範\n中間換行\n就這樣。\n'

# %%
message
# Out:
# '我來示範\n中間換行\n就這樣。\n'

# %%
print(message)
# Out:
# 我來示範
# 中間換行
# 就這樣。

# %%
m = input("美金價格： ")
# Out:
# 美金價格： 120

# %%
m
# Out:
# '120'

# %%
m*30.5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-61ab19d79956> in <module>
# ----> 1 m*30.5
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
float(m) * 30.5
# Out:
# 3660.0

# %%
m = input("美金價格： ")
TWD = float(m) * 30.5
print("折合台幣是：", TWD, "元")
print('合台幣是： ' + str(TWD) + '元')
# Out:
# 美金價格： 128
# 折合台幣是： 3904.0 元
# 合台幣是： 3904.0元

# %%
message = input(">>")
print('拍拍')
# Out:
# >>我今天很難過。
# 拍拍
